# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashraf310120/Ashraf_DS_2026/blob/main/Edukron_Pyhton_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000],
             ["C102", "Anita", "Current", 150000],
             ["C103", "Kiran", "Loan", 500000]
           ],
           [ ["C104", "Sneha", "Savings", 95000],
             ["C105", "Vikram", "Current", 275000],
             ["C106", "Meena", "Loan", 750000]
           ]
          ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
bank
# Out:
# [[[['C101', 'Rahul', 'Savings', 85000],
#    ['C102', 'Anita', 'Current', 150000],
#    ['C103', 'Kiran', 'Loan', 500000]],
#   [['C104', 'Sneha', 'Savings', 95000],
#    ['C105', 'Vikram', 'Current', 275000],
#    ['C106', 'Meena', 'Loan', 750000]]],
#  [[['C201', 'Arjun', 'Savings', 120000],
#    ['C202', 'Pooja', 'Current', 325000],
#    ['C203', 'Ramesh', 'Loan', 900000]],
#   [['C204', 'Priya', 'Savings', 45000],
#    ['C205', 'Amit', 'Current', 185000],
#    ['C206', 'Divya', 'Loan', 650000]]],
#  [[['C301', 'Nikhil', 'Savings', 78000],
#    ['C302', 'Kavya', 'Current', 240000],
#    ['C303', 'Suresh', 'Loan', 1000000]],
#   [['C304', 'Neha', 'Savings', 135000],
#    ['C305', 'Rohan', 'Current', 410000],
#    ['C306', 'Asha', 'Loan', 550000]]]]

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %%
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
bank[0][0][0]   # Rahul complete record
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
bank[0][0][1][2] # Anita's account type
# Out:
# 'Current'

# %%
bank[0][0][2][3] # Kiran loan amount
# Out:
# 500000

# %%
bank[0][1][0][0]  #Sneha's customer ID
# Out:
# 'C104'

# %%
bank[0][1][1][3] # Virkram's balance
# Out:
# 275000

# %%
bank[0][1][2]  # Meena's complete record
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
bank[1][0]
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %%
bank[1][0][0][0] # Arjun customer ID
# Out:
# 'C201'

# %%
bank[1][0][1][1] # Pooja name
# Out:
# 'Pooja'

# %%
bank[1][0][2][2] # Ramesh account type
# Out:
# 'Loan'

# %%
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
bank[1][1][0][2] # Priya's balance
# Out:
# 'Savings'

# %%
bank[1][1][1][2] # Amit's account type
# Out:
# 'Current'

# %%
bank[1][1][2][0] # Divya customer ID
# Out:
# 'C206'

# %%
bank[2][0]
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %%
bank[2][0][0][2] # Nikhil account type
# Out:
# 'Savings'

# %%
bank[2][0][1][3] # Kavya's balance
# Out:
# 240000

# %%
bank[2][0][2][3] # Suresh loan amount
# Out:
# 1000000

# %%
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
bank[2][1][0][1] # Neha's name
# Out:
# 'Neha'

# %%
bank[2][1][1] #  Rohan's complete record
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
bank[2][1][2][2] # Asha's account type
# Out:
# 'Loan'

# %%
bank[0]  # All customers in bank1
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %%
bank[0][0] # all customers in bank1, branch1
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
bank[0][1] # all customers in bank1, branch2
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
bank[1] # all customers in bank2
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %%
bank[1][0] # all customers in bank2 , branch1
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %%
bank[1][1] # all customers in bank2, branch2
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
bank[2] # all customers in bank3
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %%
bank[2][0] # all customers in bank3, branch1
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %%
bank[2][1]      # all customers in bank3, branch2
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
bank[0][0][0], bank[1][0][0], bank[2][0][0]  # first customer complete record from every bank's first branch
# Out:
# (['C101', 'Rahul', 'Savings', 85000],
#  ['C201', 'Arjun', 'Savings', 120000],
#  ['C301', 'Nikhil', 'Savings', 78000])

# %%
bank[0][0][0][1], bank[1][0][0][1], bank[2][0][0][1] # frist customer from every bank's first branch
# Out:
# ('Rahul', 'Arjun', 'Nikhil')

# %%
bank[0][1][1][1], bank[1][1][1][1], bank[2][1][1][1] # second customer from every bank's second branch
# Out:
# ('Vikram', 'Amit', 'Rohan')

# %%
bank[2][1][2][3] # loan amount of the last customer in bank3, branch2
# Out:
# 550000

# %% [markdown]
# # New Section
