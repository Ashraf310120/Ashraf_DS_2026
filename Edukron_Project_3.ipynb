# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashraf310120/Ashraf_DS_2026/blob/main/Edukron_Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a list of 5 employee names and add a new employee using append().
#
# Create a list of account numbers and add three new account numbers using extend().
#
# Insert a new customer at the beginning of a customer list using insert().
#
# Insert a transaction amount at index 3 in a list.
#
# Remove the last item from a list using pop().
#
# Remove the customer "Rahul" from a customer list using remove().
#
# Count how many times the account type "Savings" appears in a list using count().
#
# Find the index of "Current" in a list of account types using index().
#
# Reverse a list of transaction IDs using reverse().
#
# Sort a list of account balances in ascending order using sort().
#
# Sort a list of customer names in descending order using sort().
#
# Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.
#
# Clear all elements from a list using clear().
#
# Append a nested list containing a new customer's details to an existing customer list.
#
# Extend a list of branch names with another list of new branches.
#
# Remove the first occurrence of the balance 50000 from a list using remove().
#
# Pop the element at index 2 from a list and print the removed value.
#
# Count how many times the city "Bangalore" appears in a list.
#
# Reverse a list of bank names and print the result.
#
# Create a list of loan amounts and sort it in descending order.

# %%
employees = ["Ashraf", "Aftab", "Aslam", "Huzair", "Moufiq"]
employees.append("Mohamamd")
print(employees)
# Out:
# ['Ashraf', 'Aftab', 'Aslam', 'Huzair', 'Moufiq', 'Mohamamd']

# %%
accounts = [12345, 123456, 1234567]
accounts.extend([54321, 654321, 7654321])
print(accounts)
# Out:
# [123, 1234, 12345, 321, 4321, 54321]

# %%
customers = ["Lokesh", "Raju", "Ramesh", "Mohit"]
customers.insert(0, "Khushu")
print(customers)
# Out:
# ['Khushu', 'Lokesh', 'Raju', 'Ramesh', 'Mohit']

# %%
amount  = [1000, 2000, 3000, 4000]
amount.insert(3, 6000)
print(amount)
# Out:
# [1000, 2000, 3000, 6000, 4000]

# %%
x = [1, 4, 12.4, "Ashraf", "Khushu", "Rider"]
x.pop()
print(x)
# Out:
# [1, 4, 12.4, 'Ashraf', 'Khushu']

# %%
x = ["Ramesh", "Rahul", "Rohit"]
x.remove("Rahul")
print(x)
# Out:
# ['Ramesh', 'Rohit']

# %%
accounts = ["Current", "Savings", "Credit", "Savings", "Investment", "Savings"]
x = accounts.count("Savings")
print(x)
# Out:
# 3

# %%
accounts = ["Savings", "Current", "Savings", "Credit", "Savings", "Investment", "Savings"]
x = accounts.index("Current")
print(x)
# Out:
# 1

# %%
Id = [103, 113, 123, 133, 143]
Id.reverse()
print(Id)
# Out:
# [143, 133, 123, 113, 103]

# %%
balance = [2345, 1234, 7869, 12367, 6969]
balance.sort()
print(balance)
# Out:
# [1234, 2345, 6969, 7869, 12367]

# %%
names = ["Ashraf", "Shali", "Mabasha", "Aftab","Zubair", "Yamen"]
names.sort()
print(names)
# Out:
# ['Aftab', 'Ashraf', 'Mabasha', 'Shali', 'Yamen', 'Zubair']

# %%
names = ["Ashraf", "Shali", "Mabasha", "Aftab","Zubair", "Yamen"]
x = names.copy() # creats a copy
x.append("Khushu") # Modified the copied list
print(names)
print(x)
# Out:
# ['Ashraf', 'Shali', 'Mabasha', 'Aftab', 'Zubair', 'Yamen']
# ['Ashraf', 'Shali', 'Mabasha', 'Aftab', 'Zubair', 'Yamen', 'Khushu']

# %%
names = ["Ashraf", "Shali", "Mabasha", "Aftab","Zubair", "Yamen"]
names.clear()
print(names)
# Out:
# []

# %%
customers = [
    [101, "Ashraf", "Banglore"],
    [102, "Aftab", "Kadapa"]
]
customers.append([103, "Shali", "Hyderabad"])
print(customers)
# Out:
# [[101, 'Ashraf', 'Banglore'], [102, 'Aftab', 'Kadapa'], [103, 'Shali', 'Hyderabad']]

# %%
branches = ["Bpl", "Lohare", "Kadapa", "Hyderabad"]
new_branches = ["Nandyal", "Owk"]
branches.extend(new_branches)
print(branches)
# Out:
# ['Bpl', 'Lohare', 'Kadapa', 'Hyderabad', 'Nandyal', 'Owk']

# %%
balance = [10000, 20000, 50000, 30000, 40000, 50000]
balance.remove(50000)
print(balance)
# Out:
# [10000, 20000, 30000, 40000, 50000]

# %%
names = ["Ashraf", "Shali", "Mabasha", "Aftab","Zubair", "Yamen"]
x = names.pop(2)
print(x)
print("removed value:", x)
# Out:
# Mabasha
# removed value: Mabasha

# %%
city = ["Hyderabad", "Nandyal", "Bangalore", "Chennai", "Banglore"]
x = city.count("Bangalore")
print(x)
# Out:
# 1

# %%
banks = ["SBI", "Kotak", "ICICI", "Canara", "Hdfc"]
banks.reverse()
print(banks)
# Out:
# ['Hdfc', 'Canara', 'ICICI', 'Kotak', 'SBI']

# %%
loan_amounts = [15000, 20000, 250000, 10000, 5000]
loan_amounts.sort()
print(loan_amounts)
# Out:
# [5000, 10000, 15000, 20000, 250000]
